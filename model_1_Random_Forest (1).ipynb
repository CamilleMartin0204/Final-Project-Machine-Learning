# %%
# Update sklearn to prevent version mismatches
# !pip install sklearn --upgrade

# %%
# install joblib. This will be used to save your model. 
# Restart your kernel after installing 
# !pip install joblib

# %%
# how can I plot this?

# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split, cross_val_score, GridSearchCV
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# # Read the CSV and Perform Basic Data Cleaning

# %%
df = pd.read_csv("exoplanet_data.csv")
# Drop the null columns where all values are null
df = df.dropna(axis='columns', how='all')
# Drop the null rows
df = df.dropna()
df.head()
# Out:
#   koi_disposition  koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  \
# 0       CONFIRMED              0              0              0              0
# 1  FALSE POSITIVE              0              1              0              0
# 2  FALSE POSITIVE              0              1              0              0
# 3       CONFIRMED              0              0              0              0
# 4       CONFIRMED              0              0              0              0
#
#    koi_period  koi_period_err1  koi_period_err2  koi_time0bk  \
# 0   54.418383     2.479000e-04    -2.479000e-04   162.513840
# 1   19.899140     1.490000e-05    -1.490000e-05   175.850252
# 2    1.736952     2.630000e-07    -2.630000e-07   170.307565
# 3    2.525592     3.760000e-06    -3.760000e-06   171.595550
# 4    4.134435     1.050000e-05    -1.050000e-05   172.979370
#
#    koi_time0bk_err1  ...  koi_steff_err2  koi_slogg  koi_slogg_err1  \
# 0          0.003520  ...             -81      4.467           0.064
# 1          0.000581  ...            -176      4.544           0.044
# 2          0.000115  ...            -174      4.564           0.053
# 3          0.001130  ...            -211      4.438           0.070
# 4          0.001900  ...            -232      4.486           0.054
#
#    koi_slogg_err2  koi_srad  koi_srad_err1  koi_srad_err2         ra  \
# 0          -0.096     0.927          0.105         -0.061  291.93423
# 1          -0.176     0.868          0.233         -0.078  297.00482
# 2          -0.168     0.791          0.201         -0.067  285.53461
# 3          -0.210     1.046          0.334         -0.133  288.75488
# 4          -0.229     0.972          0.315         -0.105  296.28613
#
#          dec  koi_kepmag
# 0  48.141651      15.347
# 1  48.134129      15.436
# 2  48.285210      15.597
# 3  48.226200      15.509
# 4  48.224670      15.714
#
# [5 rows x 41 columns]

# %%
disp = df['koi_disposition'].to_list()
disp_map = {'CONFIRMED': 0, 'FALSE POSITIVE': 1, 'CANDIDATE': 2}
df['disp_num'] = [disp_map[d] for d in df['koi_disposition']]
matrix = df.corr()
matrix['disp_num'].sort_values(ascending=False)
# Out:
# disp_num             1.000000
# koi_steff_err1       0.173227
# koi_duration_err1    0.156587
# koi_time0bk_err1     0.147719
# koi_period           0.124647
# koi_period_err1      0.099048
# koi_steff            0.071048
# koi_time0bk          0.070445
# koi_srad_err1        0.069335
# koi_slogg_err1       0.068356
# ra                   0.063848
# koi_impact_err1      0.058572
# koi_srad             0.035999
# koi_duration         0.029554
# koi_teq              0.021275
# koi_insol_err1       0.014604
# koi_fpflag_ss        0.013503
# koi_insol            0.012070
# koi_impact           0.010607
# koi_depth            0.008694
# koi_fpflag_co        0.008531
# koi_fpflag_ec        0.008041
# koi_kepmag           0.004264
# koi_prad_err1        0.003135
# koi_depth_err1       0.001797
# koi_prad             0.001485
# koi_fpflag_nt        0.000416
# koi_prad_err2       -0.000998
# koi_depth_err2      -0.001797
# koi_impact_err2     -0.013980
# koi_insol_err2      -0.014159
# koi_model_snr       -0.016351
# koi_srad_err2       -0.036944
# dec                 -0.045244
# koi_slogg           -0.071437
# koi_tce_plnt_num    -0.095550
# koi_period_err2     -0.099048
# koi_time0bk_err2    -0.147719
# koi_steff_err2      -0.148902
# koi_duration_err2   -0.156587
# koi_slogg_err2      -0.165136
# Name: disp_num, dtype: float64

# %% [markdown]
# # Select your features (columns)

# %%
# Set features. This will also be used as your x values.
# selected_features = df[['names', 'of', 'selected', 'features', 'here']]
X = df.drop('koi_disposition', axis=1)
y = df['koi_disposition']

# %% [markdown]
# # Create a Train Test Split
#
# Use `koi_disposition` for the y values

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y)
X_train.head()
# Out:
#       koi_fpflag_nt  koi_fpflag_ss  koi_fpflag_co  koi_fpflag_ec  koi_period  \
# 4935              0              0              0              0  164.507439
# 863               0              0              0              0   51.390145
# 2103              0              0              0              0   21.416241
# 4611              0              1              0              0  209.062993
# 3306              0              0              0              0    3.436331
#
#       koi_period_err1  koi_period_err2  koi_time0bk  koi_time0bk_err1  \
# 4935         0.004520        -0.004520   212.760500          0.020900
# 863          0.000622        -0.000622   145.319200          0.010000
# 2103         0.000070        -0.000070   176.249910          0.002720
# 4611         0.000016        -0.000016   300.828345          0.000051
# 3306         0.000009        -0.000009   132.426970          0.001870
#
#       koi_time0bk_err2  ...  koi_slogg  koi_slogg_err1  koi_slogg_err2  \
# 4935         -0.020900  ...      4.382           0.114          -0.246
# 863          -0.010000  ...      4.284           0.103          -0.126
# 2103         -0.002720  ...      4.331           0.084          -0.126
# 4611         -0.000051  ...      4.420           0.072          -0.203
# 3306         -0.001870  ...      4.616           0.072          -0.044
#
#       koi_srad  koi_srad_err1  koi_srad_err2         ra        dec  \
# 4935     1.020          0.368         -0.146  296.40887  50.585171
# 863      1.292          0.224         -0.163  293.62592  39.506310
# 2103     1.180          0.212         -0.130  294.02911  39.051849
# 4611     1.024          0.320         -0.137  296.03470  44.562210
# 3306     0.651          0.057         -0.057  296.78934  47.234531
#
#       koi_kepmag  disp_num
# 4935      15.025         2
# 863       15.030         2
# 2103      13.542         0
# 4611      14.174         1
# 3306      15.710         2
#
# [5 rows x 41 columns]

# %% [markdown]
# # Pre-processing
#
# Scale the data using the MinMaxScaler and perform some feature selection

# %%
# Scale your data
scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train.astype(np.float64))

# %% [markdown]
# # Train the Model

# %%
# print(f"Training Data Score: {model2.score(X_train_scaled, y_train)}")
# print(f"Testing Data Score: {model2.score(X_test_scaled, y_test)}")
sgd_clf = SGDClassifier(random_state=42)

# %% [markdown]
# # Hyperparameter Tuning
#
# Use `GridSearchCV` to tune the model's parameters

# %%
# Create the GridSearchCV model
param_grid = {'alpha': [0.00001, 0.0001, 0.001, 0.01, 0.1],
              'epsilon': [0.01, 0.1, 0.05, 1]}
grid = GridSearchCV(sgd_clf, param_grid, verbose=3)

# %%
# Train the model with GridSearch
grid.fit(X_train_scaled, y_train)
# Out:
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# Fitting 3 folds for each of 20 candidates, totalling 60 fits
# [CV] alpha=1e-05, epsilon=0.01 .......................................
# [CV]  alpha=1e-05, epsilon=0.01, score=0.989136649514008, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.01 .......................................
# [CV]  alpha=1e-05, epsilon=0.01, score=0.7431350114416476, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.01 .......................................
# [CV]  alpha=1e-05, epsilon=0.01, score=0.9959908361970218, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.1 ........................................
# [CV]  alpha=1e-05, epsilon=0.1, score=0.989136649514008, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.1 ........................................
# [CV]  alpha=1e-05, epsilon=0.1, score=0.7431350114416476, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.1 ........................................
# [CV]  alpha=1e-05, epsilon=0.1, score=0.9959908361970218, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.05 .......................................
# [CV]  alpha=1e-05, epsilon=0.05, score=0.989136649514008, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.05 .......................................
# [CV]  alpha=1e-05, epsilon=0.05, score=0.7431350114416476, total=   0.0s
# [CV] alpha=1e-05, epsilon=0.05 .......................................
# [CV]  alpha=1e-05, epsilon=0.05, score=0.9959908361970218, total=   0.0s
# [CV] alpha=1e-05, epsilon=1 ..........................................
# [CV] .. alpha=1e-05, epsilon=1, score=0.989136649514008, total=   0.0s
# [CV] alpha=1e-05, epsilon=1 ..........................................
# [CV] . alpha=1e-05, epsilon=1, score=0.7431350114416476, total=   0.0s
# [CV] alpha=1e-05, epsilon=1 ..........................................
# [CV] . alpha=1e-05, epsilon=1, score=0.9959908361970218, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.01 ......................................
# [CV]  alpha=0.0001, epsilon=0.01, score=0.9902801600914809, total=   0.0s
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV] alpha=0.0001, epsilon=0.01 ......................................
# [CV]  alpha=0.0001, epsilon=0.01, score=0.9776887871853547, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.01 ......................................
# [CV]  alpha=0.0001, epsilon=0.01, score=0.8029782359679267, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.1 .......................................
# [CV]  alpha=0.0001, epsilon=0.1, score=0.9902801600914809, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.1 .......................................
# [CV]  alpha=0.0001, epsilon=0.1, score=0.9776887871853547, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.1 .......................................
# [CV]  alpha=0.0001, epsilon=0.1, score=0.8029782359679267, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.05 ......................................
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV]  alpha=0.0001, epsilon=0.05, score=0.9902801600914809, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.05 ......................................
# [CV]  alpha=0.0001, epsilon=0.05, score=0.9776887871853547, total=   0.0s
# [CV] alpha=0.0001, epsilon=0.05 ......................................
# [CV]  alpha=0.0001, epsilon=0.05, score=0.8029782359679267, total=   0.0s
# [CV] alpha=0.0001, epsilon=1 .........................................
# [CV]  alpha=0.0001, epsilon=1, score=0.9902801600914809, total=   0.0s
# [CV] alpha=0.0001, epsilon=1 .........................................
# [CV]  alpha=0.0001, epsilon=1, score=0.9776887871853547, total=   0.0s
# [CV] alpha=0.0001, epsilon=1 .........................................
# [CV]  alpha=0.0001, epsilon=1, score=0.8029782359679267, total=   0.0s
# [CV] alpha=0.001, epsilon=0.01 .......................................
# [CV]  alpha=0.001, epsilon=0.01, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.001, epsilon=0.01 .......................................
# [CV]  alpha=0.001, epsilon=0.01, score=0.9988558352402745, total=   0.0s
# [CV] alpha=0.001, epsilon=0.01 .......................................
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV]  alpha=0.001, epsilon=0.01, score=0.9570446735395189, total=   0.0s
# [CV] alpha=0.001, epsilon=0.1 ........................................
# [CV]  alpha=0.001, epsilon=0.1, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.001, epsilon=0.1 ........................................
# [CV]  alpha=0.001, epsilon=0.1, score=0.9988558352402745, total=   0.0s
# [CV] alpha=0.001, epsilon=0.1 ........................................
# [CV]  alpha=0.001, epsilon=0.1, score=0.9570446735395189, total=   0.0s
# [CV] alpha=0.001, epsilon=0.05 .......................................
# [CV]  alpha=0.001, epsilon=0.05, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.001, epsilon=0.05 .......................................
# [CV]  alpha=0.001, epsilon=0.05, score=0.9988558352402745, total=   0.0s
# [CV] alpha=0.001, epsilon=0.05 .......................................
# [CV]  alpha=0.001, epsilon=0.05, score=0.9570446735395189, total=   0.0s
# [CV] alpha=0.001, epsilon=1 ..........................................
# [CV] .. alpha=0.001, epsilon=1, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.001, epsilon=1 ..........................................
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV] . alpha=0.001, epsilon=1, score=0.9988558352402745, total=   0.0s
# [CV] alpha=0.001, epsilon=1 ..........................................
# [CV] . alpha=0.001, epsilon=1, score=0.9570446735395189, total=   0.0s
# [CV] alpha=0.01, epsilon=0.01 ........................................
# [CV]  alpha=0.01, epsilon=0.01, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.01, epsilon=0.01 ........................................
# [CV]  alpha=0.01, epsilon=0.01, score=0.9891304347826086, total=   0.0s
# [CV] alpha=0.01, epsilon=0.01 ........................................
# [CV]  alpha=0.01, epsilon=0.01, score=0.9919816723940436, total=   0.0s
# [CV] alpha=0.01, epsilon=0.1 .........................................
# [CV] . alpha=0.01, epsilon=0.1, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.01, epsilon=0.1 .........................................
# [CV]  alpha=0.01, epsilon=0.1, score=0.9891304347826086, total=   0.0s
# [CV] alpha=0.01, epsilon=0.1 .........................................
# [CV]  alpha=0.01, epsilon=0.1, score=0.9919816723940436, total=   0.0s
# [CV] alpha=0.01, epsilon=0.05 ........................................
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV]  alpha=0.01, epsilon=0.05, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.01, epsilon=0.05 ........................................
# [CV]  alpha=0.01, epsilon=0.05, score=0.9891304347826086, total=   0.0s
# [CV] alpha=0.01, epsilon=0.05 ........................................
# [CV]  alpha=0.01, epsilon=0.05, score=0.9919816723940436, total=   0.0s
# [CV] alpha=0.01, epsilon=1 ...........................................
# [CV] ... alpha=0.01, epsilon=1, score=0.989136649514008, total=   0.0s
# [CV] alpha=0.01, epsilon=1 ...........................................
# [CV] .. alpha=0.01, epsilon=1, score=0.9891304347826086, total=   0.0s
# [CV] alpha=0.01, epsilon=1 ...........................................
# [CV] .. alpha=0.01, epsilon=1, score=0.9919816723940436, total=   0.0s
# [CV] alpha=0.1, epsilon=0.01 .........................................
# [CV]  alpha=0.1, epsilon=0.01, score=0.9897084048027445, total=   0.0s
# [CV] alpha=0.1, epsilon=0.01 .........................................
# [CV] . alpha=0.1, epsilon=0.01, score=0.988558352402746, total=   0.0s
# [CV] alpha=0.1, epsilon=0.01 .........................................
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [CV]  alpha=0.1, epsilon=0.01, score=0.9914089347079038, total=   0.0s
# [CV] alpha=0.1, epsilon=0.1 ..........................................
# [CV] . alpha=0.1, epsilon=0.1, score=0.9897084048027445, total=   0.0s
# [CV] alpha=0.1, epsilon=0.1 ..........................................
# [CV] .. alpha=0.1, epsilon=0.1, score=0.988558352402746, total=   0.0s
# [CV] alpha=0.1, epsilon=0.1 ..........................................
# [CV] . alpha=0.1, epsilon=0.1, score=0.9914089347079038, total=   0.0s
# [CV] alpha=0.1, epsilon=0.05 .........................................
# [CV]  alpha=0.1, epsilon=0.05, score=0.9897084048027445, total=   0.0s
# [CV] alpha=0.1, epsilon=0.05 .........................................
# [CV] . alpha=0.1, epsilon=0.05, score=0.988558352402746, total=   0.0s
# [CV] alpha=0.1, epsilon=0.05 .........................................
# [CV]  alpha=0.1, epsilon=0.05, score=0.9914089347079038, total=   0.0s
# [CV] alpha=0.1, epsilon=1 ............................................
# [CV] ... alpha=0.1, epsilon=1, score=0.9897084048027445, total=   0.0s
# [CV] alpha=0.1, epsilon=1 ............................................
# [CV] .... alpha=0.1, epsilon=1, score=0.988558352402746, total=   0.0s
# [CV] alpha=0.1, epsilon=1 ............................................
# [CV] ... alpha=0.1, epsilon=1, score=0.9914089347079038, total=   0.0s
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed:    1.6s finished
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:166: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If both are left unset, they default to max_iter=5 and tol=None. If tol is not None, max_iter defaults to max_iter=1000. From 0.21, default max_iter will be 1000, and default tol will be 1e-3.
#   FutureWarning)
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=SGDClassifier(alpha=0.0001, average=False, class_weight=None,
#        early_stopping=False, epsilon=0.1, eta0=0.0, fit_intercept=True,
#        l1_ratio=0.15, learning_rate='optimal', loss='hinge', max_iter=None,
#        n_iter=None, n_iter_no_change=5, n_jobs=None, penalty='l2',
#        power_t=0.5, random_state=42, shuffle=True, tol=None,
#        validation_fraction=0.1, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'alpha': [1e-05, 0.0001, 0.001, 0.01, 0.1], 'epsilon': [0.01, 0.1, 0.05, 1]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'alpha': 0.01, 'epsilon': 0.01}
# 0.9900820141140568

# %%
#lkup
rf_param_grid = {
    'n_estimators' : [3, 10 , 30], 
    'max_features' : [2, 6, 8, 16, 24, 40]
}

# %%
#lkup
rf_clf = RandomForestClassifier()
rf_grid = GridSearchCV(rf_clf, rf_param_grid, verbose=3)
rf_grid.fit(X_train_scaled, y_train)
# Out:
# C:\Users\motie\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_split.py:2053: FutureWarning: You should specify a value for 'cv' instead of relying on the default value. The default value will change from 3 to 5 in version 0.22.
#   warnings.warn(CV_WARNING, FutureWarning)
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# Fitting 3 folds for each of 18 candidates, totalling 54 fits
# [CV] max_features=2, n_estimators=3 ..................................
# [CV]  max_features=2, n_estimators=3, score=0.888507718696398, total=   0.0s
# [CV] max_features=2, n_estimators=3 ..................................
# [CV]  max_features=2, n_estimators=3, score=0.8901601830663616, total=   0.0s
# [CV] max_features=2, n_estimators=3 ..................................
# [CV]  max_features=2, n_estimators=3, score=0.8751431844215349, total=   0.0s
# [CV] max_features=2, n_estimators=10 .................................
# [CV]  max_features=2, n_estimators=10, score=0.9817038307604345, total=   0.0s
# [CV] max_features=2, n_estimators=10 .................................
# [CV]  max_features=2, n_estimators=10, score=0.9262013729977117, total=   0.0s
# [CV] max_features=2, n_estimators=10 .................................
# [CV]  max_features=2, n_estimators=10, score=0.981672394043528, total=   0.0s
# [CV] max_features=2, n_estimators=30 .................................
# [CV]  max_features=2, n_estimators=30, score=0.9828473413379074, total=   0.1s
# [CV] max_features=2, n_estimators=30 .................................
# [CV]  max_features=2, n_estimators=30, score=0.954233409610984, total=   0.1s
# [CV] max_features=2, n_estimators=30 .................................
# [CV]  max_features=2, n_estimators=30, score=0.9822451317296678, total=   0.1s
# [CV] max_features=6, n_estimators=3 ..................................
# [CV]  max_features=6, n_estimators=3, score=0.9754145225843339, total=   0.0s
# [CV] max_features=6, n_estimators=3 ..................................
# [CV]  max_features=6, n_estimators=3, score=0.9914187643020596, total=   0.0s
# [CV] max_features=6, n_estimators=3 ..................................
# [CV]  max_features=6, n_estimators=3, score=0.9759450171821306, total=   0.0s
# [CV] max_features=6, n_estimators=10 .................................
# [CV]  max_features=6, n_estimators=10, score=0.9965694682675815, total=   0.0s
# [CV] max_features=6, n_estimators=10 .................................
# [CV]  max_features=6, n_estimators=10, score=0.9959954233409611, total=   0.0s
# [CV] max_features=6, n_estimators=10 .................................
# [CV]  max_features=6, n_estimators=10, score=0.9994272623138603, total=   0.0s
# [CV] max_features=6, n_estimators=30 .................................
# [CV]  max_features=6, n_estimators=30, score=0.9982847341337907, total=   0.2s
# [CV] max_features=6, n_estimators=30 .................................
# [CV]  max_features=6, n_estimators=30, score=0.9994279176201373, total=   0.2s
# [CV] max_features=6, n_estimators=30 .................................
# [CV]  max_features=6, n_estimators=30, score=0.9982817869415808, total=   0.2s
# [CV] max_features=8, n_estimators=3 ..................................
# [CV]  max_features=8, n_estimators=3, score=0.9965694682675815, total=   0.0s
# [CV] max_features=8, n_estimators=3 ..................................
# [CV]  max_features=8, n_estimators=3, score=0.994279176201373, total=   0.0s
# [CV] max_features=8, n_estimators=3 ..................................
# [CV]  max_features=8, n_estimators=3, score=0.9959908361970218, total=   0.0s
# [CV] max_features=8, n_estimators=10 .................................
# [CV]  max_features=8, n_estimators=10, score=0.9988564894225271, total=   0.0s
# [CV] max_features=8, n_estimators=10 .................................
# [CV]  max_features=8, n_estimators=10, score=0.9988558352402745, total=   0.0s
# [CV] max_features=8, n_estimators=10 .................................
# [CV] ....... max_features=8, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=8, n_estimators=30 .................................
# [CV] ....... max_features=8, n_estimators=30, score=1.0, total=   0.2s
# [CV] max_features=8, n_estimators=30 .................................
# [CV]  max_features=8, n_estimators=30, score=0.9994279176201373, total=   0.2s
# [CV] max_features=8, n_estimators=30 .................................
# [CV]  max_features=8, n_estimators=30, score=0.9994272623138603, total=   0.2s
# [CV] max_features=16, n_estimators=3 .................................
# [CV] ....... max_features=16, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=16, n_estimators=3 .................................
# [CV]  max_features=16, n_estimators=3, score=0.9977116704805492, total=   0.0s
# [CV] max_features=16, n_estimators=3 .................................
# [CV] ....... max_features=16, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=16, n_estimators=10 ................................
# [CV] ...... max_features=16, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=16, n_estimators=10 ................................
# [CV] ...... max_features=16, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=16, n_estimators=10 ................................
# [CV] ...... max_features=16, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=16, n_estimators=30 ................................
# [CV] ...... max_features=16, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=16, n_estimators=30 ................................
# [CV] ...... max_features=16, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=16, n_estimators=30 ................................
# [CV] ...... max_features=16, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=24, n_estimators=3 .................................
# [CV] ....... max_features=24, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=24, n_estimators=3 .................................
# [CV] ....... max_features=24, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=24, n_estimators=3 .................................
# [CV] ....... max_features=24, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=24, n_estimators=10 ................................
# [CV] ...... max_features=24, n_estimators=10, score=1.0, total=   0.1s
# [CV] max_features=24, n_estimators=10 ................................
# [CV] ...... max_features=24, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=24, n_estimators=10 ................................
# [CV] ...... max_features=24, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=24, n_estimators=30 ................................
# [CV] ...... max_features=24, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=24, n_estimators=30 ................................
# [CV] ...... max_features=24, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=24, n_estimators=30 ................................
# [CV] ...... max_features=24, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=40, n_estimators=3 .................................
# [CV] ....... max_features=40, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=40, n_estimators=3 .................................
# [CV] ....... max_features=40, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=40, n_estimators=3 .................................
# [CV] ....... max_features=40, n_estimators=3, score=1.0, total=   0.0s
# [CV] max_features=40, n_estimators=10 ................................
# [CV] ...... max_features=40, n_estimators=10, score=1.0, total=   0.1s
# [CV] max_features=40, n_estimators=10 ................................
# [CV] ...... max_features=40, n_estimators=10, score=1.0, total=   0.0s
# [CV] max_features=40, n_estimators=10 ................................
# [CV] ...... max_features=40, n_estimators=10, score=1.0, total=   0.1s
# [CV] max_features=40, n_estimators=30 ................................
# [CV] ...... max_features=40, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=40, n_estimators=30 ................................
# [CV] ...... max_features=40, n_estimators=30, score=1.0, total=   0.3s
# [CV] max_features=40, n_estimators=30 ................................
# [CV] ...... max_features=40, n_estimators=30, score=1.0, total=   0.3s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:    9.2s finished
# GridSearchCV(cv='warn', error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'n_estimators': [3, 10, 30], 'max_features': [2, 6, 8, 16, 24, 40]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring=None, verbose=3)

# %%
print(rf_grid.best_params_)
print(rf_grid.best_score_)
# Out:
# {'max_features': 16, 'n_estimators': 10}
# 1.0

# %% [markdown]
# # Save the Model

# %%
# save your model by updating "your_name" with your name
# and "your_model" with your model variable
# be sure to turn this in to BCS
# if joblib fails to import, try running the command to install in terminal/git-bash
import joblib
filename = 'MonicaO.sav'
joblib.dump(rf_clf, filename)
# Out:
# ['MonicaO.sav']

# %%
# import matplotlib.pyplot as plt
# rf_clf = rf_clf.fit(X,y)
# predictions = rf_clf.predict(X)
# plt.scatter(predictions, predictions - y)
# plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
# plt.show()
